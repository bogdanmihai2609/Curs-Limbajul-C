# %% [markdown]
# <a href="https://colab.research.google.com/github/bogdanmihai2609/Curs-Limbajul-C/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Limbajul C
#
# Autor: Mihai George-Bogdan

# %%
a=1
a=a+1
